# %%
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
import package.maths
print(package.maths.__file__)
print(dir(package.maths))
# Out:
# c:\Data Analyst\Modules\package\maths.py
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
def addition(a,b):
    return a+b
print(addition(2,3))
# Out:
# 5

# %%
from package.maths import addition
addition(2, 3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from package.maths import addition
#       2 addition(2,3)
#
# ImportError: cannot import name 'addition' from 'package.maths' (c:\Data Analyst\Modules\package\maths.py)
